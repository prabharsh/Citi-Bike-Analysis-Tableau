# %%
import pandas as pd
from functools import reduce

# %%
df1 = pd.read_csv("Resources\JC-201902-citibike-tripdata.csv\JC-201902-citibike-tripdata.csv",sep=',')
df2 = pd.read_csv("Resources\JC-201903-citibike-tripdata.csv\JC-201903-citibike-tripdata.csv",sep=',')
df3 = pd.read_csv("Resources\JC-201904-citibike-tripdata.csv\JC-201904-citibike-tripdata.csv",sep=',')
df4 = pd.read_csv("Resources\JC-201905-citibike-tripdata.csv\JC-201905-citibike-tripdata.csv",sep=',')
df5 = pd.read_csv("Resources\JC-201906-citibike-tripdata.csv\JC-201906-citibike-tripdata.csv",sep=',')
df6 = pd.read_csv("Resources\JC-201907-citibike-tripdata.csv\JC-201907-citibike-tripdata.csv",sep=',')
df7 = pd.read_csv("Resources\JC-201908-citibike-tripdata.csv\JC-201908-citibike-tripdata.csv",sep=',')
df8 = pd.read_csv("Resources\JC-201909-citibike-tripdata.csv\JC-201909-citibike-tripdata.csv",sep=',')
df9 = pd.read_csv("Resources\JC-201910-citibike-tripdata.csv\JC-201910-citibike-tripdata.csv",sep=',')
df10 = pd.read_csv("Resources\JC-201911-citibike-tripdata.csv\JC-201911-citibike-tripdata.csv",sep=',')
df11 = pd.read_csv("Resources\JC-201912-citibike-tripdata.csv\JC-201912-citibike-tripdata.csv",sep=',')
df12 = pd.read_csv("Resources\JC-202001-citibike-tripdata.csv\JC-202001-citibike-tripdata.csv",sep=',')
df13 = pd.read_csv("Resources\JC-202002-citibike-tripdata.csv\JC-202002-citibike-tripdata.csv",sep=',')
df14 = pd.read_csv("Resources\JC-202003-citibike-tripdata.csv\JC-202003-citibike-tripdata.csv",sep=',')
df15 = pd.read_csv("Resources\JC-202004-citibike-tripdata.csv\JC-202004-citibike-tripdata.csv",sep=',')
df16 = pd.read_csv("Resources\JC-202005-citibike-tripdata.csv\JC-202005-citibike-tripdata.csv",sep=',')
df17 = pd.read_csv("Resources\JC-202006-citibike-tripdata.csv\JC-202006-citibike-tripdata.csv",sep=',')
df18 = pd.read_csv("Resources\JC-202007-citibike-tripdata.csv\JC-202007-citibike-tripdata.csv",sep=',')
df19 = pd.read_csv("Resources\JC-202008-citibike-tripdata.csv\JC-202008-citibike-tripdata.csv",sep=',')
df20 = pd.read_csv("Resources\JC-202009-citibike-tripdata.csv\JC-202009-citibike-tripdata.csv",sep=',')
df21 = pd.read_csv("Resources\JC-202010-citibike-tripdata.csv\JC-202010-citibike-tripdata.csv",sep=',')
df22 = pd.read_csv("Resources\JC-202011-citibike-tripdata.csv\JC-202011-citibike-tripdata.csv",sep=',')
df23 = pd.read_csv("Resources\JC-202012-citibike-tripdata.csv\JC-202012-citibike-tripdata.csv",sep=',')
df24 = pd.read_csv("Resources\JC-202101-citibike-tripdata.csv\JC-202101-citibike-tripdata.csv",sep=',')
df25 = pd.read_csv("Resources\JC-202102-citibike-tripdata.csv\JC-202102-citibike-tripdata.csv",sep=',')
df26 = pd.read_csv("Resources\JC-202103-citibike-tripdata.csv\JC-202103-citibike-tripdata.csv",sep=',')
df27 = pd.read_csv("Resources\JC-202104-citibike-tripdata.csv\JC-202104-citibike-tripdata.csv",sep=',')
df28 = pd.read_csv("Resources\JC-202105-citibike-tripdata.csv\JC-202105-citibike-tripdata.csv",sep=',')
df29 = pd.read_csv("Resources\JC-202107-citibike-tripdata.csv\JC-202107-citibike-tripdata.csv",sep=',')
df30 = pd.read_csv("Resources\JC-202108-citibike-tripdata.csv\JC-202108-citibike-tripdata.csv",sep=',')
df31 = pd.read_csv("Resources\JC-202109-citibike-tripdata.csv\JC-202109-citibike-tripdata.csv",sep=',')
df32 = pd.read_csv("Resources\JC-202110-citibike-tripdata.csv\JC-202110-citibike-tripdata.csv",sep=',')
df33 = pd.read_csv("Resources\JC-202111-citibike-tripdata.csv\JC-202111-citibike-tripdata.csv",sep=',')
df34 = pd.read_csv("Resources\JC-202112-citibike-tripdata.csv\JC-202112-citibike-tripdata.csv",sep=',')
df35 = pd.read_csv("Resources\JC-202201-citibike-tripdata.csv\JC-202201-citibike-tripdata.csv",sep=',')
df36 = pd.read_csv("Resources\JC-202202-citibike-tripdata.csv\JC-202202-citibike-tripdata.csv",sep=',')
df37 = pd.read_csv("Resources\JC-202203-citibike-tripdata.csv\JC-202203-citibike-tripdata.csv",sep=',')
df38 = pd.read_csv("Resources\JC-202204-citibike-tripdata.csv\JC-202204-citibike-tripdata.csv",sep=',')
df39 = pd.read_csv("Resources\JC-202205-citibike-tripdata.csv\JC-202205-citibike-tripdata.csv",sep=',')
df40 = pd.read_csv("Resources\JC-202206-citibike-tripdata.csv\JC-202206-citibike-tripdata.csv",sep=',')
df41 = pd.read_csv("Resources\JC-202207-citbike-tripdata.csv\JC-202207-citbike-tripdata.csv",sep=',')
df42 = pd.read_csv("Resources\JC-202208-citibike-tripdata.csv\JC-202208-citibike-tripdata.csv",sep=',')
df43 = pd.read_csv("Resources\JC-202209-citibike-tripdata.csv\JC-202209-citibike-tripdata.csv",sep=',')
df44 = pd.read_csv("Resources\JC-202210-citibike-tripdata.csv\JC-202210-citibike-tripdata.csv",sep=',')
df45 = pd.read_csv("Resources\JC-202211-citibike-tripdata.csv\JC-202211-citibike-tripdata.csv",sep=',')
df46 = pd.read_csv("Resources\JC-202212-citibike-tripdata.csv\JC-202212-citibike-tripdata.csv",sep=',')
df47 = pd.read_csv("Resources\JC-202301-citibike-tripdata.csv\JC-202301-citibike-tripdata.csv",sep=',')
df48 = pd.read_csv("Resources\JC-202302-citibike-tripdata.csv\JC-202302-citibike-tripdata.csv",sep=',')

# %%
citibank_df_2019 = pd.concat([df1,df2,df2,df4,df5,df6,df7,df8,df9,df10,df11,df12])
citibank_df_2020 = pd.concat([df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24])
citibank_df_2021 = pd.concat([df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35])
citibank_df_2022 = pd.concat([df36,df37,df38,df39,df40,df41,df42,df43,df44,df45,df46,df47])
citibank_df_2023 = pd.concat([df47,df48])

citibike22_winter = pd.concat([df46,df35,df36])
citibike22_spring = pd.concat([df37,df38,df39])
citibike22_summer = pd.concat([df40,df41,df42])
citibike22_fall = pd.concat([df43,df44,df45])

# %%
citibank_df_2019
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               142  2019-02-01 15:35:02.0820  2019-02-01 15:37:24.1360
# 1               223  2019-02-01 17:00:46.8900  2019-02-01 17:04:30.5500
# 2               106  2019-02-01 17:08:01.3260  2019-02-01 17:09:47.4400
# 3               370  2019-02-01 17:09:31.2100  2019-02-01 17:15:41.6550
# 4               315  2019-02-01 17:19:53.2490  2019-02-01 17:25:09.1400
# ...             ...                       ...                       ...
# 26015           544  2020-01-31 23:29:29.3910  2020-01-31 23:38:33.6910
# 26016           122  2020-01-31 23:30:59.3670  2020-01-31 23:33:01.6870
# 26017           201  2020-01-31 23:42:34.8460  2020-01-31 23:45:55.8780
# 26018           300  2020-01-31 23:45:00.6800  2020-01-31 23:50:00.8740
# 26019           721  2020-01-31 23:48:35.1700  2020-02-01 00:00:36.4060
#
#        start station id          start station name  start station latitude  \
# ...

# %%
citibank_df_2020
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               841  2020-02-01 00:02:13.7650  2020-02-01 00:16:15.4720
# 1               206  2020-02-01 00:16:11.3850  2020-02-01 00:19:37.4460
# 2               859  2020-02-01 00:23:22.1090  2020-02-01 00:37:41.5060
# 3               693  2020-02-01 00:25:14.5170  2020-02-01 00:36:48.0280
# 4              1473  2020-02-01 00:32:30.5050  2020-02-01 00:57:04.3740
# ...             ...                       ...                       ...
# 11619          2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 11620           147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 11621           660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 11622           384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 11623           356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        start station id  start station name  start station latitude  \
# ...

# %%
citibank_df_2021
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      121DD7DD23CB1335    docked_bike  2021-02-03 23:11:28
# 1      FD73FB85F008349D    docked_bike  2021-02-27 16:34:05
# 2      39F9E6663CB5FDF6    docked_bike  2021-02-26 23:16:04
# 3      A64745CB0792EC6F    docked_bike  2021-02-24 16:51:50
# 4      75CC76EB9543764A    docked_bike  2021-02-24 20:44:16
# ...                 ...            ...                  ...
# 26757  439B3B4ADB37F46F  electric_bike  2022-01-03 16:07:27
# 26758  11C0F2F85CBF7623  electric_bike  2022-01-22 20:02:58
# 26759  E77502BB6C6A7ADD   classic_bike  2022-01-26 12:35:21
# 26760  75C57C18EE9980EA   classic_bike  2022-01-28 12:56:34
# 26761  2EC5621EF3DCB2FA   classic_bike  2022-01-31 12:45:16
#
#                   ended_at          start_station_name start_station_id  \
# 0      2021-02-03 23:18:28  Hoboken Ave at Monmouth St            JC105
# 1      2021-02-27 16:56:40                Newport Pkwy            JC008
# ...

# %%
citibank_df_2022
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      B7BCBC133222B04A   classic_bike  2022-02-17 11:48:16
# 1      0F9F1A0F18FD3A22  electric_bike  2022-02-02 08:31:26
# 2      44B5D106DDB509AC  electric_bike  2022-02-09 14:05:49
# 3      E1434F258C195DC6   classic_bike  2022-02-08 07:57:44
# 4      64821879B2659E35   classic_bike  2022-02-07 08:05:28
# ...                 ...            ...                  ...
# 56070  17CD2F4ABD4F6785   classic_bike  2023-01-08 02:16:19
# 56071  D75D12846E6838D0  electric_bike  2023-01-21 15:32:18
# 56072  36387397177CAA80  electric_bike  2023-01-29 14:01:15
# 56073  B66278F45420CFA0   classic_bike  2023-01-30 08:28:41
# 56074  230153A8D1F2D5F7   classic_bike  2023-01-28 17:53:21
#
#                   ended_at                            start_station_name  \
# 0      2022-02-17 11:58:30                                   Astor Place
# 1      2022-02-02 08:38:08                                   Astor Place
# ...

# %%
citibank_df_2023
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      0905B18B365C9D20   classic_bike  2023-01-28 09:18:10
# 1      B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12
# 2      5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04
# 3      E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08
# 4      323165780CA0734B   classic_bike  2023-01-21 20:44:09
# ...                 ...            ...                  ...
# 51208  ED3552E421EA7C26   classic_bike  2023-02-28 07:22:53
# 51209  BA8078D363AC17B3   classic_bike  2023-02-14 16:55:56
# 51210  D6BD5A3963CE0F4B   classic_bike  2023-02-14 10:01:33
# 51211  F4D119D1E860B032   classic_bike  2023-02-23 10:17:25
# 51212  AF7EA7EB81309151   classic_bike  2023-02-23 16:37:02
#
#                   ended_at                        start_station_name  \
# 0      2023-01-28 09:28:52  Hoboken Terminal - Hudson St & Hudson Pl
# 1      2023-01-23 20:18:27  Hoboken Terminal - Hudson St & Hudson Pl
# ...

# %%
pd.DataFrame.to_csv(citibank_df_2019, 'Resources\citi_bike_merge_2019.csv')
pd.DataFrame.to_csv(citibank_df_2020, 'Resources\citi_bike_merge_2020.csv')
pd.DataFrame.to_csv(citibank_df_2021, 'Resources\citi_bike_merge_2021.csv')
pd.DataFrame.to_csv(citibank_df_2022, 'Resources\citi_bike_merge_2022.csv')
pd.DataFrame.to_csv(citibank_df_2023, 'Resources\citi_bike_merge_2023.csv')

pd.DataFrame.to_csv(citibike22_winter,'Resources\citibike22_winter.csv')
pd.DataFrame.to_csv(citibike22_spring,'Resources\citibike22_spring.csv')
pd.DataFrame.to_csv(citibike22_summer,'Resources\citibike22_summer.csv')
pd.DataFrame.to_csv(citibike22_fall,'Resources\citibike22_fall.csv')
